# %%
import numpy as np
import pandas as pd
import datetime as dt
import json
import os
from pandas import json_normalize
import time

# %%
df = pd.read_json('/Users/neem8001/Desktop/Friends and family/1174742_response.json')
df.head()
# Out:
#                                                             data  \
# about_me       {'age': 18, 'pph': 'multi', 'sex': 'Female', '...
# access code                                                 None
# agreedTac                                                   True
# dashboardTour                                               True
# diary          [{'id': '70a6c2ea-0bbb-4a26-a076-667bc75de7e3'...
#
#                                                            token locale  \
# about_me       eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc...
# access code    eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc...
# agreedTac      eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc...
# dashboardTour  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc...
# diary          eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc...
#
#                                       end_time  latitude  longitude  \
# about_me      2023-09-27 15:33:16.870000+00:00       NaN        NaN
# access code   2023-09-27 15:33:16.870000+00:00       NaN        NaN
# agreedTac     2023-09-27 15:33:16.870000+00:00       NaN        NaN
# dashboardTour 2023-09-27 15:33:16.870000+00:00       NaN        NaN
# diary         2023-09-27 15:33:16.870000+00:00       NaN        NaN
#
#                page_count                       start_time  is_complete  \
# about_me               33 2023-09-27 15:25:36.771000+00:00        False
# access code            33 2023-09-27 15:25:36.771000+00:00        False
# agreedTac              33 2023-09-27 15:25:36.771000+00:00        False
# dashboardTour          33 2023-09-27 15:25:36.771000+00:00        False
# diary                  33 2023-09-27 15:25:36.771000+00:00        False
#
#                current_page_no current_page_name  recruitment_status_code  \
# about_me                    17   store_type_page                      NaN
# access code                 17   store_type_page                      NaN
# agreedTac                   17   store_type_page                      NaN
# dashboardTour               17   store_type_page                      NaN
# diary                       17   store_type_page                      NaN
#
#                recruitment_status_reason_code
# about_me                                  NaN
# access code                               NaN
# agreedTac                                 NaN
# dashboardTour                             NaN
# diary                                     NaN

# %%
with open('/Users/neem8001/Desktop/Friends and family/1174742_response.json') as f:
    d = json.load(f)

# %%
df2 = json_normalize(d['data'])
df2.head(3)
# Out:
#                                                diary  hhcmp service srvy_id  \
# 0  [{'id': '70a6c2ea-0bbb-4a26-a076-667bc75de7e3'...  DOTHR   RADIO    FA23
#
#    diary_id  dst_code  smplu_id  agreedTac  sample_id diary_type  ...  \
# 0    701102         3         1       True       7011      RAB1B  ...
#
#    about_me.sunday_news  about_me.survey_name about_me.local_tvnews  \
# 0                    No              about_me                    No
#
#        about_me.lang_home_freq  about_me.diary_type_code  \
# 0  mostly_spanish_some_english                         Q
#
#    about_me.incentive_amount  about_me.country_of_origin  \
# 0                         $5                          us
#
#    about_me.employment_status about_me.miles_traveled_mv  \
# 0                          No               Less than 50
#
#   about_me.newspaper_time_spent
# 0                          None
#
# [1 rows x 59 columns]
